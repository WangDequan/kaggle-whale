# %%
import cv2
import pandas as pd
import matplotlib
from matplotlib import pyplot as plt
import helper
# %matplotlib inline

# %%
ls
# Out:
# Untitled.ipynb

# %%
ls ../data/
# Out:
# cookies.txt  __MACOSX/                  train.csv      w_7489.jpg.zip
# imgs/        sample_submission.csv      train.csv.zip
# imgs.zip     sample_submission.csv.zip  w_7489.jpg

# %%
ls ../data/imgs/ | head
# Out:
# w_0.jpg
# w_10000.jpg
# w_10001.jpg
# w_10002.jpg
# w_10003.jpg
# w_10004.jpg
# w_10005.jpg
# w_10006.jpg
# w_10007.jpg
# w_10008.jpg
# ls: write error

# %% [markdown]
# ## Distribution

# %%
train_df = pd.read_csv('../data/train.csv')

# %%
train_df.head()
# Out:
#         Image      whaleID
# 0  w_7812.jpg  whale_48813
# 1  w_4598.jpg  whale_09913
# 2  w_3828.jpg  whale_45062
# 3  w_8734.jpg  whale_74162
# 4  w_3251.jpg  whale_99558

# %%
train_df['whaleID'].value_counts()
# Out:
# whale_95370    47
# whale_38681    43
# whale_28892    33
# whale_90957    30
# whale_36851    30
# whale_24458    29
# whale_85464    28
# whale_51195    28
# whale_65586    27
# whale_52749    26
# whale_89615    24
# whale_34656    24
# whale_08017    24
# whale_78280    24
# whale_68116    23
# whale_79823    23
# whale_73666    23
# whale_95091    23
# whale_70138    22
# whale_48966    22
# whale_26288    22
# whale_48813    22
# whale_87291    22
# whale_61461    21
# whale_74232    21
# whale_03227    21
# whale_87604    21
# whale_17604    21
# whale_66353    21
# whale_23821    20
#                ..
# whale_07331     2
# whale_09422     2
# whale_97440     2
# whale_69943     2
# whale_80124     2
# whale_44699     2
# whale_88085     1
# whale_77984     1
# whale_88226     1
# whale_51332     1
# whale_54497     1
# whale_90966     1
# whale_05140     1
# whale_34513     1
# whale_64299     1
# whale_89271     1
# whale_22212     1
# whale_56281     1
# whale_21655     1
# whale_88432     1
# whale_45294     1
# whale_04480     1
# whale_86081     1
# whale_08729     1
# whale_66539     1
# whale_54796     1
# whale_81915     1
# whale_22848     1
# whale_51114     1
# whale_40483     1
# dtype: int64

# %%
train_df['whaleID'].value_counts().hist()

# %% [markdown]
# As can be seen, there are a lot of whales that only have one image

# %%
img_folder='../data/imgs'

# %%
sample_whale_img='w_10001.jpg'

# %% [markdown]
# ### Sample Whale Image

# %%
helper.display_image(sample_whale_img,base_path=img_folder)
